# %% [markdown]
# # Plotting

# %%
import matplotlib.pyplot as plt

# plt.plot(liste_med_x_verdier, liste_med_y_verdier)
# plt.axis(x_start, x_slutt, y_start, y_slutt)

hx = [1, 1, 1, 3, 3, 3, 3]
hy = [0, 1000, 500, 500, 0, 1000, 0]

ex = [4, 6, 4, 4, 6, 4, 4, 6]
ey = [1000, 1000, 1000, 500, 500, 500, 0, 0]

nx = [7, 7, 9, 9]
ny = [0, 1000, 0, 1000]

rx = [10, 10, 11, 11.1, 11.2, 11.3, 11.4, 11.5, 11.6, 11.6, 11.5, 11.4, 11.3, 11.2, 11.1, 11, 10, 12]
ry = [0, 1000, 1000, 995, 990, 980, 970, 955, 940, 560, 545, 530, 520, 510, 505, 500, 500, 0]

ix = [13, 13]
iy = [0, 1000]

kx = [14, 14, 14, 16, 14, 16]
ky = [0, 1000, 500, 1000, 500, 0]


plt.plot(hx, hy)
plt.plot(ex, ey)
plt.plot(nx, ny)
plt.plot(rx, ry)
plt.plot(ix, iy)
plt.plot(kx, ky)

plt.axis((0, 17, -100, 1100))
plt.legend()
plt.show()
# Out:
# No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.

# %%
navn = ["Henrik", "Martin"]
alder = [18, 19]

plt.plot(navn, alder, linestyle="-.", marker="D", color="r")
plt.ylim(0, 20)
plt.show()

# %%
navn = ["Henrik", "Martin"]
alder = [18, 19]

plt.bar(navn, alder, color="r")
plt.ylim(0, 20)
plt.show()

# %%
land = ["Chile", "Norge", "Brasil", "Polen", "Frankrike"]
verdier = [25.8, 32.5, 66.1, 29.2, 54.6]

# Sorter to separate lister og re-assign variablene
sortert_data = sorted(zip(land, verdier), key=lambda elem: elem[1])
land = [land[0] for land in sortert_data]
verdier = [land[1] for land in sortert_data]

colors = []

# Sett farger for ulike verdier
for verdi in verdier:
    if verdi > 50:
        colors.append("orangered")
    elif verdi > 30:
        colors.append("orange")
    else:
        colors.append("forestgreen")

plt.bar(land, verdier, color=colors)
plt.show()
